# %%
# This notebook adapts code from IBM's SMI-TED (SMI-TED 289M) model in the fm4m repository.   
# Original code: https://github.com/IBM/materials 
# I modified the notebook to load our metabolite list and generate embeddings for our project.

# %%
import sys
sys.path.append("../models")
sys.path.append("../")

# %%
import torch
print(torch.__version__)
# Out:
# 2.3.1

# %%
import models.fm4m as fm4m
import pandas as pd
import numpy as np
from sklearn.svm import SVR
from sklearn.compose import TransformedTargetRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("metabolites_to_SMILES.csv")

# %%
print(f"shape of df: {df.shape}")
df.head()
# Out:
# shape of df: (301, 3)
#                Unnamed: 0        Exact Match to Standard (* = isomer family)  \
# 0  HILIC-neg_Cluster_0622  1,2,3,4-tetrahydro-1-methyl-beta-carboline-3-c...
# 1    C18-neg_Cluster_0183  1,2,3,4-tetrahydro-b-carboline-1,3-dicarboxyli...
# 2    C18-neg_Cluster_0393                                       12.13-diHOME
# 3  HILIC-neg_Cluster_0480                               1-3-7-trimethylurate
# 4    C18-neg_Cluster_0530                                     13-docosenoate
#
#                                    SMILES
# 0         CC1NC(Cc2c1[nH]c3ccccc23)C(O)=O
# 1  OC(=O)C1Cc2c([nH]c3ccccc23)C(N1)C(O)=O
# 2        CCCCCC(O)C(O)C\C=C/CCCCCCCC(O)=O
# 3       CN1C(=O)N(C)C2=C(N(C)C(=O)N2)C1=O
# 4         CCCCCCCCC=CCCCCCCCCCCCC([O-])=O

# %%
input = "SMILES"
x = list(df[input].values)

# %%
fm4m.avail_models()
# Out:
#           Model Name                                        Description
# 0            SMI-TED                 SMILES based encoder decoder model
# 1        SELFIES-TED       BART model for string based SELFIES modality
# 2          MolFormer   MolFormer model for string based SMILES modality
# 3            MHG-GED                         Molecular hypergraph model
# 4           POS-EGNN                             3D atom position model
# 5            Mordred  Baseline: A descriptor-calculation software ap...
# 6  MorganFingerprint  Baseline: Circular atom environments based des...

# %%
x_batch, _ = fm4m.get_representation(x, ["C"], model_type = 'SMI-TED', return_tensor = False)
# Out:
# Random Seed: 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# /opt/anaconda3/envs/fm4m/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Vocab size: 2393
# [INFERENCE MODE - smi-ted-Light]
# 100%|██████████| 3/3 [00:03<00:00,  1.22s/it]
# 100%|██████████| 3/3 [00:03<00:00,  1.22s/it]
# 100%|██████████| 1/1 [00:00<00:00, 38.17it/s]

# %%
x_batch.index = df["SMILES"].values

# %%
print(f"x_batch shape: {x_batch.shape}")
x_batch
# Out:
# x_batch shape: (301, 768)
#                                              0         1         2    \
# CC1NC(Cc2c1[nH]c3ccccc23)C(O)=O         0.396364 -0.479849  0.029331
# OC(=O)C1Cc2c([nH]c3ccccc23)C(N1)C(O)=O  0.373362 -0.525701  0.114096
# CCCCCC(O)C(O)C\C=C/CCCCCCCC(O)=O        0.429987 -0.495715  0.084854
# CN1C(=O)N(C)C2=C(N(C)C(=O)N2)C1=O       0.412181 -0.488206  0.068995
# CCCCCCCCC=CCCCCCCCCCCCC([O-])=O         0.306383 -0.431526  0.088750
# ...                                          ...       ...       ...
# OC(=O)/C=C/c1[nH]cnc1                   0.414063 -0.602291  0.077173
# CC(C)[C@H](N)C(O)=O                     0.269893 -0.493490  0.101624
# CC(C)[C@H](N)C(O)=O                     0.269893 -0.493490  0.101624
# O=C1NC(=O)c2[nH]cnc2N1                  0.460566 -0.499067  0.104201
# OC[C@@H](O)[C@H](O)[C@@H](O)C=O         0.480365 -0.584914  0.052779
#
#                                              3         4         5    \
# CC1NC(Cc2c1[nH]c3ccccc23)C(O)=O         0.412555  0.483709 -0.672527
# OC(=O)C1Cc2c([nH]c3ccccc23)C(N1)C(O)=O  0.410386  0.536962 -0.554213
# CCCCCC(O)C(O)C\C=C/CCCCCCCC(O)=O        0.393842  0.474923 -0.659842
# CN1C(=O)N(C)C2=C(N(C)C(=O)N2)C1=O       0.409006  0.525677 -0.660098
# CCCCCCCCC=CCCCCCCCCCCCC([O-])=O         0.408827  0.541020 -0.638241
# ...                                          ...       ...       ...
# OC(=O)/C=C/c1[nH]cnc1                   0.399463  0.376349 -0.576629
# CC(C)[C@H](N)C(O)=O                     0.418190  0.451939 -0.629112
# CC(C)[C@H](N)C(O)=O                     0.418190  0.451939 -0.629112
# O=C1NC(=O)c2[nH]cnc2N1                  0.371852  0.328459 -0.640671
# OC[C@@H](O)[C@H](O)[C@@H](O)C=O         0.449683  0.411332 -0.688341
#
#                                              6         7         8    \
# CC1NC(Cc2c1[nH]c3ccccc23)C(O)=O         1.218773  0.049687  0.792117
# OC(=O)C1Cc2c([nH]c3ccccc23)C(N1)C(O)=O  1.127852  0.100569  0.782503
# CCCCCC(O)C(O)C\C=C/CCCCCCCC(O)=O        1.207936  0.099024  0.822189
# CN1C(=O)N(C)C2=C(N(C)C(=O)N2)C1=O       1.085802  0.127317  0.819204
# CCCCCCCCC=CCCCCCCCCCCCC([O-])=O         1.247241  0.124539  0.833546
# ...                                          ...       ...       ...
# OC(=O)/C=C/c1[nH]cnc1                   1.148321  0.076537  0.827023
# CC(C)[C@H](N)C(O)=O                     1.181610  0.026472  0.871132
# CC(C)[C@H](N)C(O)=O                     1.181610  0.026472  0.871132
# O=C1NC(=O)c2[nH]cnc2N1                  1.095554  0.034319  0.824624
# OC[C@@H](O)[C@H](O)[C@@H](O)C=O         1.168228  0.082010  0.798225
#
#                                              9    ...       758       759  \
# CC1NC(Cc2c1[nH]c3ccccc23)C(O)=O         0.237337  ... -1.286233 -0.159936
# OC(=O)C1Cc2c([nH]c3ccccc23)C(N1)C(O)=O  0.229514  ... -1.301916 -0.072891
# CCCCCC(O)C(O)C\C=C/CCCCCCCC(O)=O        0.184729  ... -1.327696 -0.238864
# CN1C(=O)N(C)C2=C(N(C)C(=O)N2)C1=O       0.168899  ... -1.156412 -0.219103
# CCCCCCCCC=CCCCCCCCCCCCC([O-])=O         0.227461  ... -1.219691 -0.258938
# ...                                          ...  ...       ...       ...
# OC(=O)/C=C/c1[nH]cnc1                   0.267655  ... -1.282969 -0.164353
# CC(C)[C@H](N)C(O)=O                     0.206574  ... -1.242208 -0.096259
# CC(C)[C@H](N)C(O)=O                     0.206574  ... -1.242208 -0.096259
# O=C1NC(=O)c2[nH]cnc2N1                  0.223048  ... -1.138119 -0.156273
# OC[C@@H](O)[C@H](O)[C@@H](O)C=O         0.167557  ... -1.376701 -0.184281
#
#                                              760       761       762  \
# CC1NC(Cc2c1[nH]c3ccccc23)C(O)=O         0.113961  0.324219 -0.737211
# OC(=O)C1Cc2c([nH]c3ccccc23)C(N1)C(O)=O  0.189045  0.329801 -0.704215
# CCCCCC(O)C(O)C\C=C/CCCCCCCC(O)=O        0.233488  0.289160 -0.485545
# CN1C(=O)N(C)C2=C(N(C)C(=O)N2)C1=O       0.082331  0.297099 -0.628251
# CCCCCCCCC=CCCCCCCCCCCCC([O-])=O         0.234831  0.278468 -0.497933
# ...                                          ...       ...       ...
# OC(=O)/C=C/c1[nH]cnc1                   0.199121  0.200877 -0.717913
# CC(C)[C@H](N)C(O)=O                     0.173340  0.307831 -0.590213
# CC(C)[C@H](N)C(O)=O                     0.173340  0.307831 -0.590213
# O=C1NC(=O)c2[nH]cnc2N1                  0.123117  0.298206 -0.741723
# OC[C@@H](O)[C@H](O)[C@@H](O)C=O         0.276864  0.274017 -0.595068
#
#                                              763       764       765  \
# CC1NC(Cc2c1[nH]c3ccccc23)C(O)=O         0.671974 -0.658567  0.843720
# OC(=O)C1Cc2c([nH]c3ccccc23)C(N1)C(O)=O  0.701316 -0.683768  0.820262
# CCCCCC(O)C(O)C\C=C/CCCCCCCC(O)=O        0.575598 -0.649370  0.821234
# CN1C(=O)N(C)C2=C(N(C)C(=O)N2)C1=O       0.528107 -0.730679  0.861326
# CCCCCCCCC=CCCCCCCCCCCCC([O-])=O         0.537282 -0.646706  0.856944
# ...                                          ...       ...       ...
# OC(=O)/C=C/c1[nH]cnc1                   0.522378 -0.709920  0.920468
# CC(C)[C@H](N)C(O)=O                     0.562042 -0.686225  0.929747
# CC(C)[C@H](N)C(O)=O                     0.562042 -0.686225  0.929747
# O=C1NC(=O)c2[nH]cnc2N1                  0.483435 -0.636165  0.944731
# OC[C@@H](O)[C@H](O)[C@@H](O)C=O         0.528978 -0.577532  0.850124
#
#                                              766       767
# CC1NC(Cc2c1[nH]c3ccccc23)C(O)=O         0.621036 -0.203670
# OC(=O)C1Cc2c([nH]c3ccccc23)C(N1)C(O)=O  0.615056 -0.244778
# CCCCCC(O)C(O)C\C=C/CCCCCCCC(O)=O        0.543072 -0.091636
# CN1C(=O)N(C)C2=C(N(C)C(=O)N2)C1=O       0.635826 -0.120889
# CCCCCCCCC=CCCCCCCCCCCCC([O-])=O         0.507465  0.069915
# ...                                          ...       ...
# OC(=O)/C=C/c1[nH]cnc1                   0.585280 -0.261188
# CC(C)[C@H](N)C(O)=O                     0.671628 -0.223394
# CC(C)[C@H](N)C(O)=O                     0.671628 -0.223394
# O=C1NC(=O)c2[nH]cnc2N1                  0.637915 -0.206417
# OC[C@@H](O)[C@H](O)[C@@H](O)C=O         0.602313 -0.246999
#
# [301 rows x 768 columns]

# %%
embedding_columns = [f'emb_{i}' for i in range(x_batch.shape[1])]
x_batch.columns = embedding_columns
x_batch = x_batch.reset_index().rename(columns={"index": "SMILES"})
x_batch
# Out:
#                                      SMILES     emb_0     emb_1     emb_2  \
# 0           CC1NC(Cc2c1[nH]c3ccccc23)C(O)=O  0.396364 -0.479849  0.029331
# 1    OC(=O)C1Cc2c([nH]c3ccccc23)C(N1)C(O)=O  0.373362 -0.525701  0.114096
# 2          CCCCCC(O)C(O)C\C=C/CCCCCCCC(O)=O  0.429987 -0.495715  0.084854
# 3         CN1C(=O)N(C)C2=C(N(C)C(=O)N2)C1=O  0.412181 -0.488206  0.068995
# 4           CCCCCCCCC=CCCCCCCCCCCCC([O-])=O  0.306383 -0.431526  0.088750
# ..                                      ...       ...       ...       ...
# 296                   OC(=O)/C=C/c1[nH]cnc1  0.414063 -0.602291  0.077173
# 297                     CC(C)[C@H](N)C(O)=O  0.269893 -0.493490  0.101624
# 298                     CC(C)[C@H](N)C(O)=O  0.269893 -0.493490  0.101624
# 299                  O=C1NC(=O)c2[nH]cnc2N1  0.460566 -0.499067  0.104201
# 300         OC[C@@H](O)[C@H](O)[C@@H](O)C=O  0.480365 -0.584914  0.052779
#
#         emb_3     emb_4     emb_5     emb_6     emb_7     emb_8  ...  \
# 0    0.412555  0.483709 -0.672527  1.218773  0.049687  0.792117  ...
# 1    0.410386  0.536962 -0.554213  1.127852  0.100569  0.782503  ...
# 2    0.393842  0.474923 -0.659842  1.207936  0.099024  0.822189  ...
# 3    0.409006  0.525677 -0.660098  1.085802  0.127317  0.819204  ...
# 4    0.408827  0.541020 -0.638241  1.247241  0.124539  0.833546  ...
# ..        ...       ...       ...       ...       ...       ...  ...
# 296  0.399463  0.376349 -0.576629  1.148321  0.076537  0.827023  ...
# 297  0.418190  0.451939 -0.629112  1.181610  0.026472  0.871132  ...
# 298  0.418190  0.451939 -0.629112  1.181610  0.026472  0.871132  ...
# 299  0.371852  0.328459 -0.640671  1.095554  0.034319  0.824624  ...
# 300  0.449683  0.411332 -0.688341  1.168228  0.082010  0.798225  ...
#
#       emb_758   emb_759   emb_760   emb_761   emb_762   emb_763   emb_764  \
# 0   -1.286233 -0.159936  0.113961  0.324219 -0.737211  0.671974 -0.658567
# 1   -1.301916 -0.072891  0.189045  0.329801 -0.704215  0.701316 -0.683768
# 2   -1.327696 -0.238864  0.233488  0.289160 -0.485545  0.575598 -0.649370
# 3   -1.156412 -0.219103  0.082331  0.297099 -0.628251  0.528107 -0.730679
# 4   -1.219691 -0.258938  0.234831  0.278468 -0.497933  0.537282 -0.646706
# ..        ...       ...       ...       ...       ...       ...       ...
# 296 -1.282969 -0.164353  0.199121  0.200877 -0.717913  0.522378 -0.709920
# 297 -1.242208 -0.096259  0.173340  0.307831 -0.590213  0.562042 -0.686225
# 298 -1.242208 -0.096259  0.173340  0.307831 -0.590213  0.562042 -0.686225
# 299 -1.138119 -0.156273  0.123117  0.298206 -0.741723  0.483435 -0.636165
# 300 -1.376701 -0.184281  0.276864  0.274017 -0.595068  0.528978 -0.577532
#
#       emb_765   emb_766   emb_767
# 0    0.843720  0.621036 -0.203670
# 1    0.820262  0.615056 -0.244778
# 2    0.821234  0.543072 -0.091636
# 3    0.861326  0.635826 -0.120889
# 4    0.856944  0.507465  0.069915
# ..        ...       ...       ...
# 296  0.920468  0.585280 -0.261188
# 297  0.929747  0.671628 -0.223394
# 298  0.929747  0.671628 -0.223394
# 299  0.944731  0.637915 -0.206417
# 300  0.850124  0.602313 -0.246999
#
# [301 rows x 769 columns]

# %%
x_batch.insert(0, 'Metabolite', df['Exact Match to Standard (* = isomer family)'].values)
x_batch
# Out:
#                                             Metabolite  \
# 0    1,2,3,4-tetrahydro-1-methyl-beta-carboline-3-c...
# 1    1,2,3,4-tetrahydro-b-carboline-1,3-dicarboxyli...
# 2                                         12.13-diHOME
# 3                                 1-3-7-trimethylurate
# 4                                       13-docosenoate
# ..                                                 ...
# 296                                      urocanic acid
# 297                                             valine
# 298                                             valine
# 299                                           xanthine
# 300                                             xylose
#
#                                      SMILES     emb_0     emb_1     emb_2  \
# 0           CC1NC(Cc2c1[nH]c3ccccc23)C(O)=O  0.396364 -0.479849  0.029331
# 1    OC(=O)C1Cc2c([nH]c3ccccc23)C(N1)C(O)=O  0.373362 -0.525701  0.114096
# 2          CCCCCC(O)C(O)C\C=C/CCCCCCCC(O)=O  0.429987 -0.495715  0.084854
# 3         CN1C(=O)N(C)C2=C(N(C)C(=O)N2)C1=O  0.412181 -0.488206  0.068995
# 4           CCCCCCCCC=CCCCCCCCCCCCC([O-])=O  0.306383 -0.431526  0.088750
# ..                                      ...       ...       ...       ...
# 296                   OC(=O)/C=C/c1[nH]cnc1  0.414063 -0.602291  0.077173
# 297                     CC(C)[C@H](N)C(O)=O  0.269893 -0.493490  0.101624
# 298                     CC(C)[C@H](N)C(O)=O  0.269893 -0.493490  0.101624
# 299                  O=C1NC(=O)c2[nH]cnc2N1  0.460566 -0.499067  0.104201
# 300         OC[C@@H](O)[C@H](O)[C@@H](O)C=O  0.480365 -0.584914  0.052779
#
#         emb_3     emb_4     emb_5     emb_6     emb_7  ...   emb_758  \
# 0    0.412555  0.483709 -0.672527  1.218773  0.049687  ... -1.286233
# 1    0.410386  0.536962 -0.554213  1.127852  0.100569  ... -1.301916
# 2    0.393842  0.474923 -0.659842  1.207936  0.099024  ... -1.327696
# 3    0.409006  0.525677 -0.660098  1.085802  0.127317  ... -1.156412
# 4    0.408827  0.541020 -0.638241  1.247241  0.124539  ... -1.219691
# ..        ...       ...       ...       ...       ...  ...       ...
# 296  0.399463  0.376349 -0.576629  1.148321  0.076537  ... -1.282969
# 297  0.418190  0.451939 -0.629112  1.181610  0.026472  ... -1.242208
# 298  0.418190  0.451939 -0.629112  1.181610  0.026472  ... -1.242208
# 299  0.371852  0.328459 -0.640671  1.095554  0.034319  ... -1.138119
# 300  0.449683  0.411332 -0.688341  1.168228  0.082010  ... -1.376701
#
#       emb_759   emb_760   emb_761   emb_762   emb_763   emb_764   emb_765  \
# 0   -0.159936  0.113961  0.324219 -0.737211  0.671974 -0.658567  0.843720
# 1   -0.072891  0.189045  0.329801 -0.704215  0.701316 -0.683768  0.820262
# 2   -0.238864  0.233488  0.289160 -0.485545  0.575598 -0.649370  0.821234
# 3   -0.219103  0.082331  0.297099 -0.628251  0.528107 -0.730679  0.861326
# 4   -0.258938  0.234831  0.278468 -0.497933  0.537282 -0.646706  0.856944
# ..        ...       ...       ...       ...       ...       ...       ...
# 296 -0.164353  0.199121  0.200877 -0.717913  0.522378 -0.709920  0.920468
# 297 -0.096259  0.173340  0.307831 -0.590213  0.562042 -0.686225  0.929747
# 298 -0.096259  0.173340  0.307831 -0.590213  0.562042 -0.686225  0.929747
# 299 -0.156273  0.123117  0.298206 -0.741723  0.483435 -0.636165  0.944731
# 300 -0.184281  0.276864  0.274017 -0.595068  0.528978 -0.577532  0.850124
#
#       emb_766   emb_767
# 0    0.621036 -0.203670
# 1    0.615056 -0.244778
# 2    0.543072 -0.091636
# 3    0.635826 -0.120889
# 4    0.507465  0.069915
# ..        ...       ...
# 296  0.585280 -0.261188
# 297  0.671628 -0.223394
# 298  0.671628 -0.223394
# 299  0.637915 -0.206417
# 300  0.602313 -0.246999
#
# [301 rows x 770 columns]

# %%
x_batch.to_csv("SMI-TED289M_embeddings.csv", index=False)
